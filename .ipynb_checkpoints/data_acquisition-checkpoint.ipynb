# %%
import os.path
from pathlib import Path
import requests
import json
import pandas as pd

# %%
def initialize_cursor_data():
    file = Path('data/cursor_data.csv')
    
    if (file.exists()):
        print("initialization skipped - cursor data already exists")
    else:
        cursor_initial = {"batch": ["next"], "cursor": ['*']}

        cursor_data = pd.DataFrame(data = cursor_initial)
        cursor_data.to_csv('data/cursor_data.csv', index = False)

def get_next_cursor():
    cursor_data = pd.read_csv('data/cursor_data.csv')
    next_cursor = cursor_data.loc[-1:, 'cursor']
    next_cursor = next_cursor.to_string(index = False)
    next_cursor = next_cursor.lstrip()
    
    return next_cursor

def get_next_url(next_cursor):
    base_url = 'https://store.steampowered.com/appreviews/322330?json=1&cursor='
    next_cursor = get_next_cursor()
    next_url = base_url + next_cursor
    
    return next_url
    
def fetch_data(): # add num_batches
    cursors = []
    
    next_cursor = get_next_cursor() # get next cursor from file
    
    # start for loop
    next_url = get_next_url(next_cursor)
    
    r = requests.get(next_url)
    json_data = json.loads(r.text) 
    
    review_data = pd.DataFrame(data = json_data['reviews'])
    next_cursor = json_data['cursor']
    cursors.append(next_cursor)
    
    # end for loop
    
    return review_data, cursors

def process_review_data(review_data):
    processed_data = review_data[['author', 'review', 'voted_up']].copy()
    processed_data['author'] = processed_data['author'].apply(lambda x: x.get('steamid'))
    processed_data.rename(columns = {'author': 'steamid'}, inplace = True)
    return processed_data

def clean_data(new_data): # tokenize reviews later
    review_data = new_data[0]
    cursors = new_data[1]
    

    
    
# update data (write-back)

# %%
initialize_cursor_data()
# Out:
# initialization skipped - cursor data already exists

# %%
new_data = fetch_data()

# %%
z = process_data(new_data[0])
z
# Out:
#               steamid                                             review  \
# 0   76561198254483814         One of my favorite games to play alone. :(
# 1   76561198929746349  +One of the best survival games\n+Difficult bo...
# 2   76561198126551276                                  good with friends
# 3   76561198119086907  This is one of my favorite games, and one I al...
# 4   76561198146913622  Yes it is good but you need to play it with fr...
# 5   76561198060692740  You can play this alone, but it's not balanced...
# 6   76561198155752513  One of my all time favorite games\nthank you f...
# 7   76561198188609010        Amazing game to play alone or with friends.
# 8   76561198030812677  I haven't played the single player version of ...
# 9   76561198823568519  We can never miss any chance to grow. Especial...
# 10  76561198874787127                           Best Survival Simulator.
# 11  76561198882096909  it's not for me but i can see why people like it.
# 12  76561198165955218  I think playing over 1500 hours is enough of a...
# 13  76561198004693514  Don't Starve is hard alone, which strategy to ...
# 14  76561198071129210  Hands down the most Chris fire I've ever CHRIS...
# 15  76561198056592021                                             is gud
# 16  76561198341168476  Fun game my friend and I died on day 7 to 3 ho...
# 17  76561198039037277                                      more food plz
# 18  76561198031778597                                   I starved alone.
# 19  76561197987790360                                    best game ever.
#
#     voted_up
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8      False
# 9       True
# 10      True
# 11     False
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True

# %%
"""TO DO
    clean data:
        drop: 'recommendationid', 'language', 'timestamp_created', 'timestamp_updated',
              'votes_up', 'votes_funny', 'weighted_vote_score', 'comment_count', 
              'steam_purchase', 'received_for_free', 'written_during_early_access'
        
        map: 'author' to 'steamid' only
        
        get rid of newline characters(?)
        
    dataframe to save batch numbers and their cursors
"""

r = requests.get('https://store.steampowered.com/appreviews/322330?json=1&cursor=*')

json_data = json.loads(r.text)

#raw_review_data = pd.DataFrame(data = json_data['reviews'])

#review_data = clean_data(raw_review_data)
# base_address = 'https://store.steampowered.com/appreviews/322330?json=1&cursor='
# cursor = json_data['cursor'] # need for next batch of reviews

# next_address = base_address + cursor
# next_batch  = requests.get(next_address)

# %%
# reviews_df.loc[reviews_df['voted_up'] == 0, 'review']
# reviews_df.loc[13, 'review']
